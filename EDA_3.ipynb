# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %config InlineBackened.figure_format = 'retina'
df = pd.read_csv('/content/EDA 3/1.1) train.csv')

# %%
sns.countplot(x='Survived',data=df)

# %%
sns.countplot(x='Survived',data=df, hue='Sex')

# %%
sns.lineplot('Age',y='Fare',data= df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.plot.scatter('Age','Fare')

# %%
df.plot.scatter('Age','Survived')

# %%
df['Age'].hist(bins=8)

# %%
df['Age'].hist(bins=100)

# %%
import matplotlib.pyplot as plt 
sizes = df['Survived'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels=['Not Survived', 'Survived'],autopct ='%1.1f%%', shadow=True)
plt.show()
